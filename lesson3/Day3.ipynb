# %% [markdown]
# <a href="https://colab.research.google.com/github/CKVCU/Info450/blob/main/lesson3/Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introduction to APIs

# %%
import requests

# %%
response=requests.get("https://catfact.ninja/fact")

# %%
response.json()
# Out:
# {'fact': 'Female cats are polyestrous', 'length': 28}

# %%
data=response.json()
type(data)
# Out:
# dict

# %%
data['fact']
# Out:
# 'Female cats are polyestrous'

# %%
data['length']
# Out:
# 28

# %% [markdown]
# #World Cup API

# %%
#This is going to pull data from world cup API
url="https://raw.githubusercontent.com/openfootball/worldcup.json/master/2026/worldcup.json"
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
data=response.json()
data.keys()
data['matches']
first_match=data['matches'][0]
five_five_match=data['matches'][55]
five_five_match['score']['ft'][0]
# Out:
# 3

# %% [markdown]
# #Using my github as an API

# %%
import requests
url = "https://raw.githubusercontent.com/CKVCU/Info450/main/parts.json"
response=requests.get(url)
response
# Out:
# <Response [200]>

# %%
data=response.json()
data['parts'][1]['name']
# Out:
# 'Motherboard'

# %%
import requests

# API endpoint for historical weather
url = "https://historical-forecast-api.open-meteo.com/v1/forecast"

# Parameters for the request
params = {
"latitude": 40.7128, # Latitude for New York City
"longitude": -74.0060, # Longitude for New York City
"start_date": "2025-06-20", # Start date for the past week
"end_date": "2025-06-26", # End date for the past week
"daily": "temperature_2m_max", # Daily maximum temperature
"timezone": "auto" # Automatically adjust for timezone
}

# Fetch data from the API
response = requests.get(url, params=params)
data = response.json()

# %%
temps=data['daily']['temperature_2m_max']
temps
# Out:
# [29.5, 31.8, 32.4, 36.0, 39.1, 38.2, 30.7]

# %%
print ("Max value is", max(temps))
# Out:
# Max value is 39.1

# %%
min(temps)
# Out:
# 29.5

# %%
max(temps)
# Out:
# 39.1

# %%
range=max(temps)-min(temps)
range
# Out:
# 9.600000000000001

# %%
sum(temps)/len(temps)
# Out:
# 33.957142857142856

# %%
data['daily']
# Out:
# {'time': ['2025-06-20',
#   '2025-06-21',
#   '2025-06-22',
#   '2025-06-23',
#   '2025-06-24',
#   '2025-06-25',
#   '2025-06-26'],
#  'temperature_2m_max': [29.5, 31.8, 32.4, 36.0, 39.1, 38.2, 30.7]}
